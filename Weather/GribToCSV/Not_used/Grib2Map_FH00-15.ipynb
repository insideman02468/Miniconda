# %%
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 
import time

start = time.time()

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"

#timestomp like 201808010000 means that it is at 2019/04/09/08:00(UTC timezone)
year = "2019"
month = "04"
day = "22"
roottime="000000"
FH="00-15"

def getgrib(year,month,day,roottime,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/")\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day,time,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"   
    return "grib_data/"+file_name

# %%
print(os.path.isfile( getrootgrib(year,month,day,roottime,FH) ))
# Out:
# True

# %%
grbs = getgrib(year,month,day,roottime,FH)
latlons = grbs

# %%
print(os.path.isfile( getrootgrib(year,month,day,roottime,FH) ))
# Out:
# True

# %%
#check parameters in gribfile
grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

# lats,lonsは二次元配列で緯度経度が入っている
lats, lons = grb_1.latlons()

#一次元に変換
# 二次元のままでは描画できない
# 2次元の格子点を1次元配列にならす
flat_lats= np.ravel(lats)
flat_lons= np.ravel(lons)

pd_rad= {'lons':flat_lons, 'lats':flat_lats}
pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
pd_temp= {'lons':flat_lons, 'lats':flat_lats}

i,j,k,l =0,0,0,0

for grb in grbs:
    print(grb)
    
    if grb.name == "Downward short-wave radiation flux":
        radiation = grb.values
        flat_radiation = np.ravel(radiation)
        pd_name="radiation FH"+str(i)+"-"+str(i+1)+"W/m2(avg)"
        pd_rad[pd_name]=flat_radiation
        i=i+1

    elif grb.name == "10 metre U wind component":
        Uwind = grb.values
        flat_Uwind = np.ravel(Uwind)
        pd_name="Uwind FH"+str(j)+"m/s"
        pd_Uwind[pd_name]=flat_Uwind
        j=j+1

    elif grb.name == "10 metre V wind component":
        Vwind = grb.values
        flat_Vwind = np.ravel(Vwind)
        pd_name="Vwind FH"+str(k)+"m/s"
        pd_Vwind[pd_name]=flat_Vwind
        k=k+1

    elif grb.name == "Temperature":
        temperature = grb.values
        #華氏を摂氏に変換
        flat_temperature= np.ravel(temperature)
        flat_temperature=flat_temperature-273.115
        pd_name="temperature FH"+str(l)
        pd_temp[pd_name]=flat_temperature
        l=l+1
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201904220000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201904220000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201904220000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201904220000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201904220000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201904220000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201904220000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201904220000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201904220000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201904220000
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201904220000
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201904220000
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201904220000
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201904220000
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201904220000
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201904220000
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201904220000
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201904220000
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201904220000
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201904220000
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201904220000
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201904220000
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201904220000
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201904220000
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201904220000
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201904220000
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201904220000
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201904220000
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201904220000
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201904220000
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201904220000
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201904220000
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201904220000
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201904220000
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201904220000
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201904220000
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201904220000
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201904220000
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201904220000
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201904220000
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201904220000
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201904220000
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201904220000
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201904220000
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201904220000
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201904220000
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201904220000
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201904220000
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201904220000
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201904220000
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201904220000
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201904220000
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201904220000
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201904220000
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201904220000
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201904220000
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201904220000
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201904220000
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201904220000
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201904220000
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201904220000
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201904220000
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201904220000
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201904220000
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201904220000
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201904220000
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201904220000
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201904220000
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201904220000
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201904220000
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201904220000
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201904220000
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201904220000
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201904220000
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201904220000
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201904220000
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201904220000
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201904220000
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201904220000
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201904220000
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201904220000
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201904220000
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201904220000
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201904220000
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201904220000
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201904220000
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201904220000
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201904220000
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201904220000
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201904220000
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201904220000
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201904220000
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201904220000
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201904220000
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201904220000
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201904220000
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201904220000
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201904220000
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201904220000
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201904220000
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201904220000
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201904220000
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201904220000
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201904220000
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201904220000
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201904220000
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201904220000
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201904220000
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201904220000
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201904220000
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201904220000
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201904220000
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201904220000
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201904220000
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201904220000
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201904220000
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201904220000
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201904220000
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201904220000
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201904220000
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201904220000
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201904220000
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201904220000
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201904220000
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201904220000
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201904220000
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201904220000
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201904220000
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201904220000
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201904220000
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201904220000
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201904220000
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201904220000
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201904220000
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201904220000
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201904220000
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201904220000
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201904220000
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201904220000
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201904220000
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201904220000
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201904220000
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201904220000
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201904220000
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201904220000
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201904220000
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201904220000
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201904220000
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201904220000
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201904220000
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201904220000
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201904220000
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201904220000
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201904220000
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201904220000
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201904220000
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201904220000
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201904220000
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201904220000
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201904220000
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201904220000
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201904220000
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201904220000
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201904220000
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201904220000
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201904220000
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201904220000
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201904220000
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201904220000
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201904220000
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201904220000
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201904220000
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201904220000
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201904220000
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201904220000
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201904220000
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201904220000
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201904220000
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201904220000
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201904220000
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201904220000
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201904220000
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201904220000
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201904220000
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201904220000
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201904220000
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201904220000
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201904220000
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201904220000
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201904220000

# %%
#緯度経度の範囲を選択
east_lon=130.438
west_lon= 130.437
north_lat=33.555
south_lat=33.550

# %%
#range adjust
def range_ajust(east_lon,west_lon,north_lat,south_lat,df_all):
    df=df_all[df_all['lons'] > west_lon]
    df=df[df['lons'] < east_lon]

    df=df[df['lats'] > south_lat]
    df=df[df['lats'] < north_lat]
    return df

# %% [markdown]
# ## Select parameter temperature, Uwind, Vwind, radiation

# %%
########################
df_para = "Uwind"
########################

if df_para == "temperature":
    df_input=pd.DataFrame(pd_temp)

elif df_para == "Uwind":
    df_input=pd.DataFrame(pd_Uwind)
   
elif df_para == "Vwind":
    df_input=pd.DataFrame(pd_Vwind)
    
elif df_para == "radiation":
    df_input=pd.DataFrame(pd_rad)
    


df = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input)
map_lat=df['lats'].values
map_lon=df['lons'].values
df = np.round(df,2)
print(len(df))
df[:10]
# Out:
# 1
#           lons   lats  Uwind FH0m/s  Uwind FH1m/s  Uwind FH2m/s  Uwind FH3m/s  \
# 135328  130.44  33.55          0.12         -0.07          0.43          1.17
#
#         Uwind FH4m/s  Uwind FH5m/s  Uwind FH6m/s  Uwind FH7m/s  Uwind FH8m/s  \
# 135328          1.28          0.83          0.92          1.01          1.26
#
#         Uwind FH9m/s  Uwind FH10m/s  Uwind FH11m/s  Uwind FH12m/s  \
# 135328          1.62           1.41           1.19           0.94
#
#         Uwind FH13m/s  Uwind FH14m/s  Uwind FH15m/s
# 135328           0.51           0.17          -0.21

# %%
FH0=df.iloc[:,2].values
FH1=df.iloc[:,3].values
FH2=df.iloc[:,4].values
FH3=df.iloc[:,5].values
FH4=df.iloc[:,6].values
FH5=df.iloc[:,7].values
FH6=df.iloc[:,8].values
FH7=df.iloc[:,9].values
FH8=df.iloc[:,10].values
FH9=df.iloc[:,11].values
FH10=df.iloc[:,12].values
FH11=df.iloc[:,13].values
FH12=df.iloc[:,14].values
FH13=df.iloc[:,15].values
FH14=df.iloc[:,16].values
FH15=df.iloc[:,17].values

# %%
from folium import plugins

#lat-long of focus area and zoom start
map = folium.Map([33.518022,130.471583], zoom_start=12)

# Mapbox makes some nice map tiles,
# Stamen also produce some cool map tiles which typically work at all zoom levels.
tile = folium.TileLayer('Stamen Terrain').add_to(map)

#adding marker and popup of temperature
for i in range(0,len(map_lat)):
    
    icon_number = plugins.BeautifyIcon(
    border_color='#00ABDC',
    text_color='#00ABDC',
    border_width=2,
    number=str(int(FH0[i])),
    inner_icon_style='margin-top:0;')
    
    folium.Marker(location=[float(map_lat[i])  ,float(map_lon[i])],\
                  popup="___"+df_para+"___"+"\n"\
                          +"__lat= "+str(map_lat[i])+"__\n"\
                          +"__lon= "+str(map_lon[i])+"__\n"\
                          +"__FH0 = "+str(FH0[i])+"__\n"\
                          +"__FH1 = "+str(FH1[i])+"__\n"\
                          +"__FH2 = "+str(FH2[i])+"__\n"\
                          +"__FH3 = "+str(FH3[i])+"__\n"\
                          +"__FH4 = "+str(FH4[i])+"__\n"\
                          +"__FH5 = "+str(FH5[i])+"__\n"\
                          +"__FH6 = "+str(FH6[i])+"__\n"\
                          +"__FH7 = "+str(FH7[i])+"__\n"\
                          +"__FH8 = "+str(FH8[i])+"__\n"\
                          +"__FH9 = "+str(FH9[i])+"__\n"\
                          +"__FH10 = "+str(FH10[i])+"__\n"\
                          +"__FH11 = "+str(FH11[i])+"__\n"\
                          +"__FH12 = "+str(FH12[i])+"__\n"\
                          +"__FH13 = "+str(FH13[i])+"__\n"\
                          +"__FH14 = "+str(FH14[i])+"__\n"\
                          #+"__FH15 = "+str(FH15[i])+"__\n"\
                          ,\
                 icon=icon_number).add_to(map)
    
#we can change tiles with help of LayerConrol
folium.LayerControl().add_to(map)

#Adding mouse position
formatter = "function(num) {return L.Util.formatNum(num, 3) + ' º ';};"

folium.plugins.MousePosition(
    position='topright',
    separator=' | ',
    empty_string='NaN',
    lng_first=True,
    num_digits=20,
    prefix='Coordinates:',
    lat_formatter=formatter,
    lng_formatter=formatter
).add_to(map)

map_name="Output_MAP/"+"FH_"+FH+"_"+df_para+"_Map_" + year + "_" + month + "_" + day+ "_" + roottime+".html"
csv_name="Output_CSV/"+"FH_"+FH+"_"+df_para + year + "_" + month + "_" + day+ "_" + roottime+".csv"

df.to_csv(csv_name, encoding='utf-8', index=False)
map.save(outfile=map_name)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
elapsed_time = time.time() - start

print("elapsed_time:{0}".format(elapsed_time))
# Out:
# elapsed_time:1.717902660369873
