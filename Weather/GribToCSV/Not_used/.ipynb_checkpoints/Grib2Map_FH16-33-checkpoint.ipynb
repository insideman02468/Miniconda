# %%
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 
import time

start = time.time()

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"

#timestomp like 201808010000 means that it is at 2019/04/09/08:00(UTC timezone)
year = "2019"
month = "04"
day = "22"
roottime="000000"
FH="16-33"

def getgrib(year,month,day,roottime,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/")\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day,time,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"   
    return "grib_data/"+file_name

# %%
print(os.path.isfile( getrootgrib(year,month,day,roottime,FH) ))
# Out:
# True

# %%
grbs = getgrib(year,month,day,roottime,FH)
latlons = grbs

# %%
print(os.path.isfile( getrootgrib(year,month,day,roottime,FH) ))
# Out:
# True

# %%
#check parameters in gribfile
grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

# lats,lonsは二次元配列で緯度経度が入っている
lats, lons = grb_1.latlons()

#一次元に変換
# 二次元のままでは描画できない
# 2次元の格子点を1次元配列にならす
flat_lats= np.ravel(lats)
flat_lons= np.ravel(lons)

pd_rad= {'lons':flat_lons, 'lats':flat_lats}
pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
pd_temp= {'lons':flat_lons, 'lats':flat_lats}

i,j,k,l =0,0,0,0

for grb in grbs:
    print(grb)
    
    if grb.name == "Downward short-wave radiation flux":
        radiation = grb.values
        flat_radiation = np.ravel(radiation)
        pd_name="radiation FH"+str(i+16)+"-"+str(i+17)+"W/m2(avg)"
        pd_rad[pd_name]=flat_radiation
        i=i+1

    elif grb.name == "10 metre U wind component":
        Uwind = grb.values
        flat_Uwind = np.ravel(Uwind)
        pd_name="Uwind FH"+str(j+16)+"m/s"
        pd_Uwind[pd_name]=flat_Uwind
        j=j+1

    elif grb.name == "10 metre V wind component":
        Vwind = grb.values
        flat_Vwind = np.ravel(Vwind)
        pd_name="Vwind FH"+str(k+16)+"m/s"
        pd_Vwind[pd_name]=flat_Vwind
        k=k+1

    elif grb.name == "Temperature":
        temperature = grb.values
        #華氏を摂氏に変換
        flat_temperature= np.ravel(temperature)
        flat_temperature=flat_temperature-273.115
        pd_name="temperature FH"+str(l+16)
        pd_temp[pd_name]=flat_temperature
        l=l+1
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 16 hrs:from 201904220000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201904220000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 16 hrs:from 201904220000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 16 hrs:from 201904220000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 16 hrs:from 201904220000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 16 hrs:from 201904220000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201904220000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201904220000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201904220000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201904220000
# 11:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 15-16 hrs (accum):from 201904220000
# 12:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 15-16 hrs (avg):from 201904220000
# 13:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 17 hrs:from 201904220000
# 14:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201904220000
# 15:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 17 hrs:from 201904220000
# 16:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 17 hrs:from 201904220000
# 17:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 17 hrs:from 201904220000
# 18:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 17 hrs:from 201904220000
# 19:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201904220000
# 20:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201904220000
# 21:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201904220000
# 22:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201904220000
# 23:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 16-17 hrs (accum):from 201904220000
# 24:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 16-17 hrs (avg):from 201904220000
# 25:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 18 hrs:from 201904220000
# 26:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201904220000
# 27:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 18 hrs:from 201904220000
# 28:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 18 hrs:from 201904220000
# 29:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 18 hrs:from 201904220000
# 30:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 18 hrs:from 201904220000
# 31:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201904220000
# 32:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201904220000
# 33:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201904220000
# 34:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201904220000
# 35:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 17-18 hrs (accum):from 201904220000
# 36:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 17-18 hrs (avg):from 201904220000
# 37:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 19 hrs:from 201904220000
# 38:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201904220000
# 39:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 19 hrs:from 201904220000
# 40:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 19 hrs:from 201904220000
# 41:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 19 hrs:from 201904220000
# 42:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 19 hrs:from 201904220000
# 43:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201904220000
# 44:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201904220000
# 45:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201904220000
# 46:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201904220000
# 47:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 18-19 hrs (accum):from 201904220000
# 48:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 18-19 hrs (avg):from 201904220000
# 49:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 20 hrs:from 201904220000
# 50:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201904220000
# 51:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 20 hrs:from 201904220000
# 52:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 20 hrs:from 201904220000
# 53:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 20 hrs:from 201904220000
# 54:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 20 hrs:from 201904220000
# 55:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201904220000
# 56:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201904220000
# 57:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201904220000
# 58:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201904220000
# 59:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 19-20 hrs (accum):from 201904220000
# 60:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 19-20 hrs (avg):from 201904220000
# 61:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 21 hrs:from 201904220000
# 62:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201904220000
# 63:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 21 hrs:from 201904220000
# 64:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 21 hrs:from 201904220000
# 65:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 21 hrs:from 201904220000
# 66:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 21 hrs:from 201904220000
# 67:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201904220000
# 68:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201904220000
# 69:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201904220000
# 70:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201904220000
# 71:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 20-21 hrs (accum):from 201904220000
# 72:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 20-21 hrs (avg):from 201904220000
# 73:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 22 hrs:from 201904220000
# 74:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201904220000
# 75:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 22 hrs:from 201904220000
# 76:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 22 hrs:from 201904220000
# 77:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 22 hrs:from 201904220000
# 78:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 22 hrs:from 201904220000
# 79:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201904220000
# 80:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201904220000
# 81:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201904220000
# 82:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201904220000
# 83:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 21-22 hrs (accum):from 201904220000
# 84:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 21-22 hrs (avg):from 201904220000
# 85:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 23 hrs:from 201904220000
# 86:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201904220000
# 87:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 23 hrs:from 201904220000
# 88:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 23 hrs:from 201904220000
# 89:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 23 hrs:from 201904220000
# 90:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 23 hrs:from 201904220000
# 91:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201904220000
# 92:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201904220000
# 93:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201904220000
# 94:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201904220000
# 95:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 22-23 hrs (accum):from 201904220000
# 96:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 22-23 hrs (avg):from 201904220000
# 97:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 24 hrs:from 201904220000
# 98:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201904220000
# 99:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 24 hrs:from 201904220000
# 100:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 24 hrs:from 201904220000
# 101:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 24 hrs:from 201904220000
# 102:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 24 hrs:from 201904220000
# 103:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201904220000
# 104:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201904220000
# 105:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201904220000
# 106:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201904220000
# 107:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 23-24 hrs (accum):from 201904220000
# 108:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 23-24 hrs (avg):from 201904220000
# 109:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 25 hrs:from 201904220000
# 110:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201904220000
# 111:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 25 hrs:from 201904220000
# 112:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 25 hrs:from 201904220000
# 113:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 25 hrs:from 201904220000
# 114:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 25 hrs:from 201904220000
# 115:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201904220000
# 116:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201904220000
# 117:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201904220000
# 118:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201904220000
# 119:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 24-25 hrs (accum):from 201904220000
# 120:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 24-25 hrs (avg):from 201904220000
# 121:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 26 hrs:from 201904220000
# 122:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201904220000
# 123:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 26 hrs:from 201904220000
# 124:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 26 hrs:from 201904220000
# 125:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 26 hrs:from 201904220000
# 126:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 26 hrs:from 201904220000
# 127:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201904220000
# 128:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201904220000
# 129:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201904220000
# 130:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201904220000
# 131:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 25-26 hrs (accum):from 201904220000
# 132:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 25-26 hrs (avg):from 201904220000
# 133:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 27 hrs:from 201904220000
# 134:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201904220000
# 135:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 27 hrs:from 201904220000
# 136:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 27 hrs:from 201904220000
# 137:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 27 hrs:from 201904220000
# 138:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 27 hrs:from 201904220000
# 139:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201904220000
# 140:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201904220000
# 141:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201904220000
# 142:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201904220000
# 143:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 26-27 hrs (accum):from 201904220000
# 144:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 26-27 hrs (avg):from 201904220000
# 145:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 28 hrs:from 201904220000
# 146:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201904220000
# 147:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 28 hrs:from 201904220000
# 148:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 28 hrs:from 201904220000
# 149:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 28 hrs:from 201904220000
# 150:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 28 hrs:from 201904220000
# 151:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201904220000
# 152:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201904220000
# 153:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201904220000
# 154:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201904220000
# 155:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 27-28 hrs (accum):from 201904220000
# 156:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 27-28 hrs (avg):from 201904220000
# 157:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 29 hrs:from 201904220000
# 158:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201904220000
# 159:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 29 hrs:from 201904220000
# 160:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 29 hrs:from 201904220000
# 161:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 29 hrs:from 201904220000
# 162:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 29 hrs:from 201904220000
# 163:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201904220000
# 164:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201904220000
# 165:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201904220000
# 166:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201904220000
# 167:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 28-29 hrs (accum):from 201904220000
# 168:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 28-29 hrs (avg):from 201904220000
# 169:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 30 hrs:from 201904220000
# 170:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201904220000
# 171:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 30 hrs:from 201904220000
# 172:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 30 hrs:from 201904220000
# 173:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 30 hrs:from 201904220000
# 174:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 30 hrs:from 201904220000
# 175:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201904220000
# 176:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201904220000
# 177:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201904220000
# 178:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201904220000
# 179:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 29-30 hrs (accum):from 201904220000
# 180:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 29-30 hrs (avg):from 201904220000
# 181:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 31 hrs:from 201904220000
# 182:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201904220000
# 183:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 31 hrs:from 201904220000
# 184:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 31 hrs:from 201904220000
# 185:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 31 hrs:from 201904220000
# 186:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 31 hrs:from 201904220000
# 187:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201904220000
# 188:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201904220000
# 189:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201904220000
# 190:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201904220000
# 191:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 30-31 hrs (accum):from 201904220000
# 192:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 30-31 hrs (avg):from 201904220000
# 193:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 32 hrs:from 201904220000
# 194:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201904220000
# 195:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 32 hrs:from 201904220000
# 196:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 32 hrs:from 201904220000
# 197:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 32 hrs:from 201904220000
# 198:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 32 hrs:from 201904220000
# 199:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201904220000
# 200:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201904220000
# 201:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201904220000
# 202:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201904220000
# 203:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 31-32 hrs (accum):from 201904220000
# 204:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 31-32 hrs (avg):from 201904220000
# 205:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 33 hrs:from 201904220000
# 206:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201904220000
# 207:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 33 hrs:from 201904220000
# 208:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 33 hrs:from 201904220000
# 209:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 33 hrs:from 201904220000
# 210:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 33 hrs:from 201904220000
# 211:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201904220000
# 212:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201904220000
# 213:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201904220000
# 214:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201904220000
# 215:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 32-33 hrs (accum):from 201904220000
# 216:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 32-33 hrs (avg):from 201904220000

# %%
#緯度経度の範囲を選択
east_lon=130.438
west_lon= 130.437
north_lat=33.555
south_lat=33.550

# %%
#range adjust
def range_ajust(east_lon,west_lon,north_lat,south_lat,df_all):
    df=df_all[df_all['lons'] > west_lon]
    df=df[df['lons'] < east_lon]

    df=df[df['lats'] > south_lat]
    df=df[df['lats'] < north_lat]
    return df

# %% [markdown]
# ## Select parameter temperature, Uwind, Vwind, radiation

# %%
########################
df_para = "Uwind"
########################

if df_para == "temperature":
    df_input=pd.DataFrame(pd_temp)

elif df_para == "Uwind":
    df_input=pd.DataFrame(pd_Uwind)
   
elif df_para == "Vwind":
    df_input=pd.DataFrame(pd_Vwind)
    
elif df_para == "radiation":
    df_input=pd.DataFrame(pd_rad)
    


df = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input)
map_lat=df['lats'].values
map_lon=df['lons'].values
df = np.round(df,2)
print(len(df))

df[:10]
# Out:
# 1
#           lons   lats  Uwind FH16m/s  Uwind FH17m/s  Uwind FH18m/s  \
# 135328  130.44  33.55          -0.67          -0.87          -0.93
#
#         Uwind FH19m/s  Uwind FH20m/s  Uwind FH21m/s  Uwind FH22m/s  \
# 135328          -1.04          -1.09           -1.0          -1.03
#
#         Uwind FH23m/s  Uwind FH24m/s  Uwind FH25m/s  Uwind FH26m/s  \
# 135328          -1.37           -1.4          -1.22          -0.98
#
#         Uwind FH27m/s  Uwind FH28m/s  Uwind FH29m/s  Uwind FH30m/s  \
# 135328          -0.82           -0.1           0.31           0.43
#
#         Uwind FH31m/s  Uwind FH32m/s  Uwind FH33m/s
# 135328           0.37           0.32          -0.21

# %%
FH16=df.iloc[:,2].values
FH17=df.iloc[:,3].values
FH18=df.iloc[:,4].values
FH19=df.iloc[:,5].values
FH20=df.iloc[:,6].values
FH21=df.iloc[:,7].values
FH22=df.iloc[:,8].values
FH23=df.iloc[:,9].values
FH24=df.iloc[:,10].values
FH25=df.iloc[:,11].values
FH26=df.iloc[:,12].values
FH27=df.iloc[:,13].values
FH28=df.iloc[:,14].values
FH29=df.iloc[:,15].values
FH30=df.iloc[:,16].values
FH31=df.iloc[:,17].values
FH32=df.iloc[:,18].values
FH33=df.iloc[:,19].values

# %%
from folium import plugins

#lat-long of focus area and zoom start
map = folium.Map([33.518022,130.471583], zoom_start=12)

# Mapbox makes some nice map tiles,
# Stamen also produce some cool map tiles which typically work at all zoom levels.
tile = folium.TileLayer('Stamen Terrain').add_to(map)

#adding marker and popup of temperature
for i in range(0,len(map_lat)):
    
    icon_number = plugins.BeautifyIcon(
    border_color='#00ABDC',
    text_color='#00ABDC',
    border_width=2,
    number=str(int(FH16[i])),
    inner_icon_style='margin-top:0;')
    
    folium.Marker(location=[float(map_lat[i])  ,float(map_lon[i])],\
                  popup="___"+df_para+"___"+"\n"\
                          +"__lat= "+str(map_lat[i])+"__\n"\
                          +"__lon= "+str(map_lon[i])+"__\n"\
                          +"__FH16 = "+str(FH16[i])+"__\n"\
                          +"__FH17 = "+str(FH17[i])+"__\n"\
                          +"__FH18 = "+str(FH18[i])+"__\n"\
                          +"__FH19 = "+str(FH19[i])+"__\n"\
                          +"__FH20 = "+str(FH20[i])+"__\n"\
                          +"__FH21 = "+str(FH21[i])+"__\n"\
                          +"__FH22 = "+str(FH22[i])+"__\n"\
                          +"__FH23 = "+str(FH23[i])+"__\n"\
                          +"__FH24 = "+str(FH24[i])+"__\n"\
                          +"__FH25 = "+str(FH25[i])+"__\n"\
                          +"__FH26 = "+str(FH26[i])+"__\n"\
                          +"__FH27 = "+str(FH27[i])+"__\n"\
                          +"__FH28 = "+str(FH28[i])+"__\n"\
                          +"__FH29 = "+str(FH29[i])+"__\n"\
                          +"__FH30 = "+str(FH30[i])+"__\n"\
                          +"__FH31 = "+str(FH31[i])+"__\n"\
                          +"__FH32 = "+str(FH32[i])+"__\n"\
                          +"__FH33 = "+str(FH33[i])+"__\n",\
                 icon=icon_number).add_to(map)
    
#we can change tiles with help of LayerConrol
folium.LayerControl().add_to(map)

#Adding mouse position
formatter = "function(num) {return L.Util.formatNum(num, 3) + ' º ';};"

folium.plugins.MousePosition(
    position='topright',
    separator=' | ',
    empty_string='NaN',
    lng_first=True,
    num_digits=20,
    prefix='Coordinates:',
    lat_formatter=formatter,
    lng_formatter=formatter
).add_to(map)

map_name="Output_MAP/"+"FH_"+FH+"_"+df_para+"_Map_" + year + "_" + month + "_" + day+ "_" + roottime+".html"
csv_name="Output_CSV/"+"FH_"+FH+"_"+df_para + year + "_" + month + "_" + day+ "_" + roottime+".csv"

df.to_csv(csv_name, encoding='utf-8', index=False)
map.save(outfile=map_name)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
elapsed_time = time.time() - start

print("elapsed_time:{0}".format(elapsed_time))
# Out:
# elapsed_time:1.9956045150756836
