# %%
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"
year = "2018"
month = "01"
day = "01"

def getgrib(year,month,day):
    file_name = "Z__C_RJTD_"+str(year+month+day)+"000000_MSM_GPV_Rjp_Lsurf_FH00-15_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/" )\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day):
    file_name = "Z__C_RJTD_"+str(year+month+day)+"000000_MSM_GPV_Rjp_Lsurf_FH00-15_grib2.bin"    
    return "grib_data/"+file_name

# %%
print(os.path.isfile( getrootgrib(year,month,day) ))
# Out:
# True

# %%
grbs = getgrib(year,month,day)

# %%
print(os.path.isfile( getrootgrib(year,month,day) ))
# Out:
# True

# %%
#check parameters in gribfile
for grb in grbs:
    print(grb)
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201801010000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201801010000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201801010000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201801010000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201801010000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201801010000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201801010000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201801010000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201801010000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201801010000
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201801010000
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201801010000
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201801010000
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201801010000
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201801010000
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201801010000
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201801010000
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201801010000
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201801010000
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201801010000
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201801010000
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201801010000
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201801010000
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201801010000
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201801010000
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201801010000
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201801010000
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201801010000
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201801010000
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201801010000
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201801010000
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201801010000
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201801010000
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201801010000
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201801010000
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201801010000
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201801010000
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201801010000
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201801010000
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201801010000
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201801010000
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201801010000
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201801010000
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201801010000
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201801010000
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201801010000
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201801010000
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201801010000
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201801010000
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201801010000
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201801010000
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201801010000
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201801010000
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201801010000
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201801010000
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201801010000
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201801010000
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201801010000
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201801010000
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 
10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201801010000
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201801010000
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201801010000
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201801010000
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201801010000
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201801010000
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201801010000
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201801010000
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201801010000
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201801010000
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201801010000
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201801010000
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201801010000
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201801010000
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201801010000
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201801010000
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201801010000
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201801010000
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201801010000
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201801010000
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201801010000
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201801010000
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201801010000
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201801010000
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201801010000
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201801010000
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201801010000
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201801010000
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201801010000
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201801010000
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201801010000
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201801010000
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201801010000
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201801010000

# %%
# lats,lonsは二次元配列で緯度経度が入っている
lats, lons = grb.latlons()

#一次元に変換
# 二次元のままでは描画できない
# 2次元の格子点を1次元配列にならす
flat_lats= np.ravel(lats)
flat_lons= np.ravel(lons)

pd_all= {'lons':flat_lons, 'lats':flat_lats}

#ID 27 is Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201801010000
# selectメソッドで指定した要素(forecastTime=0)にマッチする要素の配列が返ってくる。
# forecastTime=0の要素は複数あるが先頭([0])はTempratureが入っている

for i in range(0,6):
    grb = grbs.select(forecastTime=i)[5]
    # 中に含まれているデータ(temprature)を二次元のndarrayで取り出す
    temperature = grb.values
    #華氏を摂氏に変換
    flat_temperature= (np.ravel(temperature)-32)/1.8
    pd_name="temperature FH"+str(i)
    pd_all[pd_name]=flat_temperature
    
df_all= pd.DataFrame(pd_all)
print(len(df_all))
df_all[:10]
# Out:
# 242905
#        lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  120.0000  47.6        24.523277        24.472344        23.830435
# 1  120.0625  47.6        26.398277        24.316094        23.604741
# 2  120.1250  47.6        26.658694        24.333455        23.326963
# 3  120.1875  47.6        25.842722        24.420260        23.535296
# 4  120.2500  47.6        26.120500        24.889010        23.760991
# 5  120.3125  47.6        26.450361        25.166788        23.813074
# 6  120.3750  47.6        26.380916        25.548733        23.986685
# 7  120.4375  47.6        26.901750        25.878594        24.264463
# 8  120.5000  47.6        27.214250        25.670260        24.125574
# 9  120.5625  47.6        26.867027        25.045260        23.361685
#
#    temperature FH3  temperature FH4  temperature FH5
# 0        23.843983        23.788818        23.891104
# 1        23.705094        23.667290        23.786937
# 2        23.288427        23.181179        23.300826
# 3        23.114816        22.816596        22.918882
# 4        23.236344        22.851318        22.918882
# 5        23.236344        22.799235        22.866799
# 6        23.323150        22.816596        22.866799
# 7        23.583566        23.042290        23.109854
# 8        23.479400        23.007568        23.127215
# 9        22.628705        22.139513        22.311243

# %%
#緯度経度の範囲を選択
east_lon=131.775
west_lon=130.0
north_lat=34
south_lat=33.0

# %%
#range adjust
df=df_all[df_all['lons'] > west_lon]
df=df[df['lons'] < east_lon]

df=df[df['lats'] > south_lat]
df=df[df['lats'] < north_lat]
print(len(df))
df[:10]
# Out:
# 560
#             lons   lats  temperature FH0  temperature FH1  temperature FH2  \
# 131474  130.0625  33.95        14.419111        15.427205        17.042241
# 131475  130.1250  33.95        14.332305        15.357760        16.712379
# 131476  130.1875  33.95        14.158694        15.184149        16.139463
# 131477  130.2500  33.95        13.915638        14.889010        15.514463
# 131478  130.3125  33.95        13.689944        14.611233        15.010991
# 131479  130.3750  33.95        13.516333        14.385538        14.663768
# 131480  130.4375  33.95        13.377444        14.229288        14.455435
# 131481  130.5000  33.95        13.238555        14.090399        14.316546
# 131482  130.5625  33.95        13.186472        14.055677        14.299185
# 131483  130.6250  33.95        13.186472        14.038316        14.281824
#
#         temperature FH3  temperature FH4  temperature FH5
# 131474        16.882177        16.410346        15.557771
# 131475        16.899539        16.479790        15.401521
# 131476        16.847455        16.410346        15.297354
# 131477        16.725927        16.340902        15.332076
# 131478        16.552316        16.306179        15.418882
# 131479        16.361344        16.323540        15.575132
# 131480        16.153011        16.392985        15.800826
# 131481        15.909955        16.479790        16.026521
# 131482        15.701622        16.583957        16.304299
# 131483        15.475927        16.688124        16.616799

# %%
map_lat=df['lats'].values
map_lon=df['lons'].values
FH0=np.round(df['temperature FH0'].values,2)
FH1=np.round(df['temperature FH1'].values,2)
FH2=np.round(df['temperature FH2'].values,2)
FH3=np.round(df['temperature FH3'].values,2)
FH4=np.round(df['temperature FH4'].values,2)
FH5=np.round(df['temperature FH5'].values,2)

# %%
from folium import plugins
#lat-long of focus area and zoom start
map = folium.Map([33.518022,130.471583], zoom_start=12)

# Mapbox makes some nice map tiles,
# Stamen also produce some cool map tiles which typically work at all zoom levels.
tile = folium.TileLayer('Stamen Terrain').add_to(map)

#adding marker and popup of temperature
for i in range(0,len(map_lat)):
    
    icon_number = plugins.BeautifyIcon(
    border_color='#00ABDC',
    text_color='#00ABDC',
    border_width=2,
    number=str(int(FH0[i])),
    inner_icon_style='margin-top:0;')
    
    folium.Marker(location=[float(map_lat[i])  ,float(map_lon[i])],\
                  popup="___temperature___"+"\n"\
                          +"__FH0= "+str(FH0[i])+"__\n"\
                          +"__FH1 = "+str(FH1[i])+"\__n"\
                          +"__FH2 = "+str(FH2[i])+"\__n"\
                          +"__FH3 = "+str(FH3[i])+"\__n"\
                          +"__FH4 = "+str(FH4[i])+"\__n"\
                          +"__FH5 = "+str(FH5[i])+"\__n",\
                 icon=icon_number).add_to(map)
    
#we can change tiles with help of LayerConrol
folium.LayerControl().add_to(map)

map_name="FH_Temperature Map: " + year + "/" + month + "/" + day
map.save(outfile="map_name")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
