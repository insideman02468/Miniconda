# %%
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"
year = "2018"
month = "08"
day = "01"

def getgrib(year,month,day):
    file_name = "Z__C_RJTD_"+str(year+month+day)+"000000_MSM_GPV_Rjp_Lsurf_FH00-15_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/" )\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day):
    file_name = "Z__C_RJTD_"+str(year+month+day)+"000000_MSM_GPV_Rjp_Lsurf_FH00-15_grib2.bin"    
    return "grib_data/"+file_name

# %%
print(os.path.isfile( getrootgrib(year,month,day) ))
# Out:
# False

# %%
grbs = getgrib(year,month,day)

# %%
print(os.path.isfile( getrootgrib(year,month,day) ))
# Out:
# True

# %%
#check parameters in gribfile
for grb in grbs:
    print(grb)
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201808010000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201808010000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201808010000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201808010000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201808010000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201808010000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201808010000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201808010000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201808010000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201808010000
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201808010000
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201808010000
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201808010000
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201808010000
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201808010000
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201808010000
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201808010000
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201808010000
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201808010000
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201808010000
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201808010000
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201808010000
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201808010000
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201808010000
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201808010000
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201808010000
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201808010000
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201808010000
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201808010000
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201808010000
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201808010000
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201808010000
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201808010000
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201808010000
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201808010000
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201808010000
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201808010000
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201808010000
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201808010000
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201808010000
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201808010000
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201808010000
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201808010000
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201808010000
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201808010000
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201808010000
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201808010000
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201808010000
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201808010000
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201808010000
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201808010000
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201808010000
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201808010000
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201808010000
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201808010000
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201808010000
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201808010000
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201808010000
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201808010000
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201808010000
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201808010000
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201808010000
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201808010000
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201808010000
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201808010000
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201808010000
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201808010000
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201808010000
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201808010000
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201808010000
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201808010000
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201808010000
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201808010000
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201808010000
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201808010000
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201808010000
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201808010000
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201808010000
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201808010000
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201808010000
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201808010000
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201808010000
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201808010000
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201808010000
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201808010000
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201808010000
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201808010000
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201808010000
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201808010000
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201808010000
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201808010000
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201808010000
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201808010000
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201808010000
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201808010000
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201808010000
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201808010000
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201808010000
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201808010000
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201808010000
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201808010000
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201808010000
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201808010000
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201808010000
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201808010000
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201808010000
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201808010000
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201808010000
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201808010000
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201808010000
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201808010000
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201808010000
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201808010000
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201808010000
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201808010000
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201808010000
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201808010000
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201808010000
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201808010000
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201808010000
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201808010000
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201808010000
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201808010000
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201808010000
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201808010000
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201808010000
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201808010000
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201808010000
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201808010000
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201808010000
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201808010000
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201808010000
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201808010000
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201808010000
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201808010000
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201808010000
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201808010000
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201808010000
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201808010000
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201808010000
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201808010000
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201808010000
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201808010000
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201808010000
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201808010000
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201808010000
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201808010000
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201808010000
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201808010000
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201808010000
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201808010000
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201808010000
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201808010000
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201808010000
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201808010000
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201808010000
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201808010000
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201808010000
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201808010000
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201808010000
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201808010000
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201808010000
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201808010000
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201808010000
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201808010000
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201808010000
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201808010000
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201808010000
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201808010000
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201808010000
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201808010000
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201808010000
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201808010000
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201808010000
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201808010000
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201808010000
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201808010000
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201808010000
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201808010000
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201808010000
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201808010000
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201808010000
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201808010000
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201808010000
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201808010000
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201808010000
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201808010000
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201808010000
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201808010000
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201808010000

# %%
# lats,lonsは二次元配列で緯度経度が入っている
lats, lons = grb.latlons()

#一次元に変換
# 二次元のままでは描画できない
# 2次元の格子点を1次元配列にならす
flat_lats= np.ravel(lats)
flat_lons= np.ravel(lons)

pd_all= {'lons':flat_lons, 'lats':flat_lats}

#ID 27 is Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201801010000
# selectメソッドで指定した要素(forecastTime=0)にマッチする要素の配列が返ってくる。
# forecastTime=0の要素は複数あるが先頭([0])はTempratureが入っている

for i in range(0,6):
    grb = grbs.select(forecastTime=i)[5]
    # 中に含まれているデータ(temprature)を二次元のndarrayで取り出す
    temperature = grb.values
    #華氏を摂氏に変換
    flat_temperature= (np.ravel(temperature)-32)/1.8
    pd_name="temperature FH"+str(i)
    pd_all[pd_name]=flat_temperature
    
df_all= pd.DataFrame(pd_all)
print(len(df_all))
df_all[:10]
# Out:
# 242905
#        lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  120.0000  47.6        18.279455        15.649609        12.724281
# 1  120.0625  47.6        18.088483        15.441276        12.672198
# 2  120.1250  47.6        18.019038        14.955165        12.168725
# 3  120.1875  47.6        17.966955        14.712109        11.734698
# 4  120.2500  47.6        18.262094        14.764192        11.630531
# 5  120.3125  47.6        18.348899        14.729470        11.526364
# 6  120.3750  47.6        18.088483        14.677387        11.474281
# 7  120.4375  47.6        17.949594        14.816276        11.665253
# 8  120.5000  47.6        17.949594        14.781553        11.752059
# 9  120.5625  47.6        17.064177        13.739887        11.005531
#
#    temperature FH3  temperature FH4  temperature FH5
# 0        10.939543         9.564295         8.538890
# 1        10.904821         9.546934         8.538890
# 2        10.383987         9.060823         8.104863
# 3         9.880515         8.609434         7.705557
# 4         9.776349         8.522628         7.636113
# 5         9.654821         8.383739         7.497224
# 6         9.463849         8.140684         7.254168
# 7         9.550654         8.175406         7.219446
# 8         9.706904         8.314295         7.306252
# 9         8.977737         7.585128         6.542363

# %%
#緯度経度の範囲を選択
east_lon=131.69
west_lon=129.4337
north_lat=34.1413
south_lat=31.01

# %%
#range adjust
df=df_all[df_all['lons'] > west_lon]
df=df[df['lons'] < east_lon]

df=df[df['lats'] > south_lat]
df=df[df['lats'] < north_lat]
print(len(df))
df[:10]
# Out:
# 2294
#             lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 130021  129.4375  34.1        24.841955        26.187803        26.404836
# 130022  129.5000  34.1        25.015566        26.326692        26.404836
# 130023  129.5625  34.1        25.189177        26.396137        26.422198
# 130024  129.6250  34.1        25.362788        26.430859        26.456920
# 130025  129.6875  34.1        25.519038        26.430859        26.509003
# 130026  129.7500  34.1        25.692649        26.413498        26.578448
# 130027  129.8125  34.1        25.831538        26.396137        26.630531
# 130028  129.8750  34.1        25.970427        26.413498        26.682614
# 130029  129.9375  34.1        26.039872        26.448220        26.682614
# 130030  130.0000  34.1        25.987788        26.500303        26.630531
#
#         temperature FH3  temperature FH4  temperature FH5
# 130021        26.859682        26.612906        26.264585
# 130022        26.929126        26.578184        26.229863
# 130023        26.911765        26.526100        26.177779
# 130024        26.842321        26.456656        26.160418
# 130025        26.772876        26.369850        26.177779
# 130026        26.686071        26.300406        26.177779
# 130027        26.581904        26.213600        26.212502
# 130028        26.477737        26.092073        26.247224
# 130029        26.356210        25.987906        26.247224
# 130030        26.234682        25.953184        26.177779

# %%
map_lat=df['lats'].values
map_lon=df['lons'].values
FH0=np.round(df['temperature FH0'].values,2)
FH1=np.round(df['temperature FH1'].values,2)
FH2=np.round(df['temperature FH2'].values,2)
FH3=np.round(df['temperature FH3'].values,2)
FH4=np.round(df['temperature FH4'].values,2)
FH5=np.round(df['temperature FH5'].values,2)

# %%
from folium import plugins
#lat-long of focus area and zoom start
map = folium.Map([33.518022,130.471583], zoom_start=12)

# Mapbox makes some nice map tiles,
# Stamen also produce some cool map tiles which typically work at all zoom levels.
tile = folium.TileLayer('Stamen Terrain').add_to(map)

#adding marker and popup of temperature
for i in range(0,len(map_lat)):
    
    icon_number = plugins.BeautifyIcon(
    border_color='#00ABDC',
    text_color='#00ABDC',
    border_width=2,
    number=str(int(FH0[i])),
    inner_icon_style='margin-top:0;')
    
    folium.Marker(location=[float(map_lat[i])  ,float(map_lon[i])],\
                  popup="___temperature___"+"\n"\
                          +"__FH0= "+str(FH0[i])+"__\n"\
                          +"__FH1 = "+str(FH1[i])+"__\n"\
                          +"__FH2 = "+str(FH2[i])+"__\n"\
                          +"__FH3 = "+str(FH3[i])+"__\n"\
                          +"__FH4 = "+str(FH4[i])+"__\n"\
                          +"__FH5 = "+str(FH5[i])+"__\n",\
                 icon=icon_number).add_to(map)
    
#we can change tiles with help of LayerConrol
folium.LayerControl().add_to(map)

map_name="Output_MAP/"+"FH_Temperature_Map_" + year + "_" + month + "_" + day+".html"
map.save(outfile=map_name)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
