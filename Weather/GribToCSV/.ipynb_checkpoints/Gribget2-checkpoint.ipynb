# %%
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 
import time

start = time.time()

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"

#緯度経度の範囲を選択
east_lon=130.400
west_lon= 130.370
north_lat=33.62
south_lat=33.57

#timestomp like 201808010000 means that it is at 2019/04/09/08:00(UTC timezone)
year = "2019"
month = "05"
day = "6"
day2 = "13"
roottime="120000"

def getgrib(year,month,day,roottime,FH):
    
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/")\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day,time,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"   
    return "grib_data/"+file_name

# %%
while int(day) < int(day2):
                     
    if int(day) < 10 :
        day="0"+day
    
    FH="00-15"
    
    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i)+"-"+str(i+1)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    #range adjust
    def range(df):
        df=df[df['lons'] > west_lon]
        df=df[df['lons'] < east_lon]
        df=df[df['lats'] > south_lat]
        df=df[df['lats'] < north_lat]
        return df

    def range_ajust(east_lon,west_lon,north_lat,south_lat,df_all1):
        df=range(df_all1)
        return df

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    print(df_temp)
    
    new_dir_path="Output_CSV/"+year+"/"+month+"/"+day
    os.makedirs(new_dir_path,exist_ok=True)

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="16-33"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+16)+"-"+str(i+17)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+16)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+16)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+16)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="34-39"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+34)+"-"+str(i+35)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+34)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+34)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+34)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="40-51"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+40)+"-"+str(i+41)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+40)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+40)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+40)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)
    
    day=int(day)
    day2=int(day2)
    
    if day == day2:
        print('break!')
        break
    else:
        day=day+1
        
    day=str(day)
    day2=str(day2)
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201905061200
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905061200
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905061200
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905061200
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905061200
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905061200
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905061200
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905061200
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905061200
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905061200
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201905061200
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905061200
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905061200
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905061200
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905061200
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905061200
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905061200
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905061200
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905061200
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905061200
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201905061200
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201905061200
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201905061200
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905061200
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905061200
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905061200
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905061200
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905061200
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905061200
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905061200
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905061200
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905061200
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201905061200
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201905061200
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201905061200
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905061200
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905061200
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905061200
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905061200
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905061200
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905061200
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905061200
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905061200
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905061200
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201905061200
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201905061200
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201905061200
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905061200
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905061200
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905061200
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905061200
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905061200
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905061200
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905061200
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905061200
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905061200
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201905061200
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201905061200
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201905061200
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905061200
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905061200
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905061200
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905061200
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905061200
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905061200
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905061200
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905061200
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905061200
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201905061200
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201905061200
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201905061200
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905061200
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905061200
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905061200
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905061200
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905061200
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905061200
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905061200
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905061200
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905061200
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201905061200
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201905061200
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201905061200
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905061200
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905061200
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905061200
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905061200
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905061200
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905061200
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905061200
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905061200
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905061200
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201905061200
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201905061200
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201905061200
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905061200
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905061200
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905061200
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905061200
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905061200
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905061200
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905061200
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905061200
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905061200
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201905061200
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201905061200
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201905061200
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905061200
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905061200
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905061200
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905061200
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905061200
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905061200
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905061200
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905061200
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905061200
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201905061200
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201905061200
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201905061200
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905061200
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905061200
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905061200
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905061200
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905061200
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905061200
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905061200
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905061200
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905061200
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201905061200
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201905061200
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201905061200
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905061200
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905061200
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905061200
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905061200
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905061200
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905061200
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905061200
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905061200
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905061200
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201905061200
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201905061200
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201905061200
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905061200
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905061200
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905061200
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905061200
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905061200
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905061200
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905061200
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905061200
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905061200
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201905061200
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201905061200
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201905061200
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905061200
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905061200
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905061200
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905061200
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905061200
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905061200
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905061200
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905061200
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905061200
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201905061200
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201905061200
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201905061200
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905061200
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905061200
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905061200
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905061200
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905061200
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905061200
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905061200
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905061200
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905061200
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201905061200
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201905061200
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201905061200
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905061200
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905061200
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905061200
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905061200
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905061200
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905061200
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905061200
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905061200
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905061200
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201905061200
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201905061200
#     index     lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  134846  130.375  33.6         15.96816        15.168112        14.805471
#
#    temperature FH3  temperature FH4  temperature FH5  temperature FH6  \
# 0        14.415334        14.053152        13.757803        13.500387
#
#    temperature FH7  temperature FH8  temperature FH9  temperature FH10  \
# 0        13.149862        12.893575        12.474783         12.580923
#
#    temperature FH11  temperature FH12  temperature FH13  temperature FH14  \
# 0         13.398336         14.463613         15.641378         16.291128
#
#    temperature FH15
# 0         16.158468
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201905071200
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905071200
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905071200
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905071200
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905071200
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905071200
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905071200
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905071200
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905071200
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905071200
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201905071200
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905071200
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905071200
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905071200
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905071200
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905071200
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905071200
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905071200
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905071200
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905071200
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201905071200
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201905071200
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201905071200
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905071200
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905071200
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905071200
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905071200
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905071200
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905071200
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905071200
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905071200
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905071200
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201905071200
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201905071200
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201905071200
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905071200
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905071200
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905071200
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905071200
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905071200
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905071200
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905071200
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905071200
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905071200
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201905071200
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201905071200
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201905071200
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905071200
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905071200
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905071200
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905071200
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905071200
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905071200
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905071200
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905071200
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905071200
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201905071200
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201905071200
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201905071200
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905071200
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905071200
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905071200
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905071200
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905071200
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905071200
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905071200
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905071200
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905071200
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201905071200
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201905071200
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201905071200
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905071200
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905071200
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905071200
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905071200
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905071200
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905071200
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905071200
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905071200
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905071200
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201905071200
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201905071200
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201905071200
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905071200
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905071200
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905071200
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905071200
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905071200
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905071200
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905071200
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905071200
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905071200
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201905071200
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201905071200
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201905071200
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905071200
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905071200
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905071200
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905071200
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905071200
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905071200
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905071200
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905071200
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905071200
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201905071200
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201905071200
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201905071200
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905071200
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905071200
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905071200
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905071200
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905071200
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905071200
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905071200
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905071200
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905071200
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201905071200
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201905071200
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201905071200
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905071200
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905071200
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905071200
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905071200
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905071200
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905071200
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905071200
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905071200
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905071200
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201905071200
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201905071200
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201905071200
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905071200
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905071200
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905071200
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905071200
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905071200
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905071200
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905071200
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905071200
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905071200
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201905071200
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201905071200
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201905071200
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905071200
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905071200
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905071200
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905071200
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905071200
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905071200
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905071200
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905071200
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905071200
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201905071200
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201905071200
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201905071200
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905071200
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905071200
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905071200
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905071200
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905071200
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905071200
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905071200
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905071200
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905071200
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201905071200
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201905071200
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201905071200
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905071200
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905071200
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905071200
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905071200
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905071200
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905071200
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905071200
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905071200
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905071200
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201905071200
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201905071200
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201905071200
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905071200
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905071200
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905071200
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905071200
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905071200
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905071200
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905071200
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905071200
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905071200
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201905071200
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201905071200
#     index     lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  134846  130.375  33.6        15.774984        14.958853        14.451345
#
#    temperature FH3  temperature FH4  temperature FH5  temperature FH6  \
# 0        14.049764        13.740865        13.487844        13.292593
#
#    temperature FH7  temperature FH8  temperature FH9  temperature FH10  \
# 0        13.142019         13.07308        12.969778          13.36437
#
#    temperature FH11  temperature FH12  temperature FH13  temperature FH14  \
# 0         13.988699         15.209219         16.428304         17.107198
#
#    temperature FH15
# 0         17.374624
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201905081200
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905081200
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905081200
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201905081200
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905081200
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201905081200
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905081200
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905081200
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905081200
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201905081200
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201905081200
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905081200
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905081200
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201905081200
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905081200
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201905081200
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905081200
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905081200
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905081200
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201905081200
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201905081200
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201905081200
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201905081200
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905081200
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905081200
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201905081200
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905081200
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201905081200
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905081200
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905081200
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905081200
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201905081200
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201905081200
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201905081200
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201905081200
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905081200
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905081200
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201905081200
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905081200
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201905081200
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905081200
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905081200
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905081200
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201905081200
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201905081200
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201905081200
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201905081200
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905081200
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905081200
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905081200
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905081200
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905081200
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905081200
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905081200
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905081200
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905081200
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201905081200
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201905081200
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201905081200
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905081200
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905081200
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905081200
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905081200
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905081200
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905081200
# ...
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201905121200
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201905121200
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905121200
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905121200
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201905121200
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905121200
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201905121200
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905121200
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905121200
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905121200
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201905121200
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201905121200
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201905121200
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201905121200
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905121200
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905121200
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201905121200
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905121200
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201905121200
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905121200
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905121200
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905121200
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201905121200
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201905121200
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201905121200
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201905121200
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905121200
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905121200
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201905121200
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905121200
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201905121200
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905121200
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905121200
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905121200
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201905121200
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201905121200
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201905121200
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201905121200
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905121200
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905121200
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201905121200
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905121200
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201905121200
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905121200
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905121200
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905121200
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201905121200
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201905121200
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201905121200
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201905121200
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905121200
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905121200
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201905121200
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905121200
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201905121200
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905121200
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905121200
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905121200
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201905121200
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201905121200
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201905121200
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201905121200
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905121200
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905121200
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201905121200
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905121200
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201905121200
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905121200
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905121200
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905121200
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201905121200
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201905121200
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201905121200
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201905121200
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905121200
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905121200
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201905121200
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905121200
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201905121200
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905121200
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905121200
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905121200
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201905121200
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201905121200
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201905121200
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201905121200
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905121200
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905121200
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201905121200
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905121200
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201905121200
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905121200
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905121200
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905121200
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201905121200
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201905121200
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201905121200
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201905121200
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905121200
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905121200
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201905121200
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905121200
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201905121200
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905121200
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905121200
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905121200
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201905121200
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201905121200
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201905121200
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201905121200
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905121200
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905121200
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201905121200
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905121200
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201905121200
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905121200
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905121200
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905121200
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201905121200
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201905121200
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201905121200
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201905121200
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905121200
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905121200
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201905121200
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905121200
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201905121200
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905121200
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905121200
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905121200
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201905121200
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201905121200
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201905121200
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201905121200
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905121200
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905121200
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201905121200
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905121200
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201905121200
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905121200
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905121200
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905121200
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201905121200
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201905121200
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201905121200
#     index     lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  134846  130.375  33.6         18.65563        18.300894        17.926779
#
#    temperature FH3  temperature FH4  temperature FH5  temperature FH6  \
# 0        17.482595        17.285085        17.187063        16.819662
#
#    temperature FH7  temperature FH8  temperature FH9  temperature FH10  \
# 0        16.561117         16.47167          16.4746         17.289999
#
#    temperature FH11  temperature FH12  temperature FH13  temperature FH14  \
# 0         18.742117          19.72994          20.37673         20.786611
#
#    temperature FH15
# 0         20.710684

# %%
elapsed_time = time.time() - start

print("elapsed_time:{0}".format(elapsed_time))
# Out:
# elapsed_time:49.36781597137451

# %%
#緯度経度の範囲を選択
east_lon=130.400
west_lon= 130.370
north_lat=33.62
south_lat=33.57
df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
df_temp
# Out:
#     index     lons  lats  temperature FH40  temperature FH41  \
# 0  134846  130.375  33.6         21.498312         21.506155
#
#    temperature FH42  temperature FH43  temperature FH44  temperature FH45  \
# 0          21.34844         20.895071         20.474966         20.012899
#
#    temperature FH46  temperature FH47  temperature FH48  temperature FH49  \
# 0         19.533926         19.391805         19.135275         19.035787
#
#    temperature FH50  temperature FH51
# 0         18.782064         18.490865
