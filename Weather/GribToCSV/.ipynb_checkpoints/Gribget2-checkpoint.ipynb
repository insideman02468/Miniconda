# %%
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api
import pandas as pd
import os
import sys
import math
import folium
import csv 
import time

start = time.time()

# %matplotlib inline

root = os.getcwd()
root_data = root + "/grib_data"
root_URL = "http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/gpv/original/"

#緯度経度の範囲を選択
east_lon=130.400
west_lon= 130.370
north_lat=33.62
south_lat=33.57

#timestomp like 201808010000 means that it is at 2019/04/09/08:00(UTC timezone)
year = "2019"
month = "06"
day = "15"
day2 = "17"
roottime="000000"

def getgrib(year,month,day,roottime,FH):
    
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"
    file_url = root_URL\
                +str(year + "/" + month + "/" + day +"/")\
                +file_name
    root_file= "grib_data/"+file_name
    if os.path.isfile(root_file) == False:
            command = "wget -P grib_data/ "+ file_url
            os.system(command)

    getgrib_output = pygrib.open(root_file)
    return getgrib_output

def getrootgrib(year,month,day,time,FH):
    file_name = "Z__C_RJTD_"+str(year+month+day+roottime)+"_MSM_GPV_Rjp_Lsurf_FH"+str(FH)+"_grib2.bin"   
    return "grib_data/"+file_name

# %%
while int(day) < int(day2):
                     
    if int(day) < 10 :
        day="0"+day
    
    FH="00-15"
    
    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i)+"-"+str(i+1)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    #range adjust
    def range(df):
        df=df[df['lons'] > west_lon]
        df=df[df['lons'] < east_lon]
        df=df[df['lats'] > south_lat]
        df=df[df['lats'] < north_lat]
        return df

    def range_ajust(east_lon,west_lon,north_lat,south_lat,df_all1):
        df=range(df_all1)
        return df

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    print(df_temp)
    
    new_dir_path="Output_CSV/"+year+"/"+month+"/"+day
    os.makedirs(new_dir_path,exist_ok=True)

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="16-33"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+16)+"-"+str(i+17)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+16)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+16)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+16)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="34-39"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+34)+"-"+str(i+35)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+34)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+34)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+34)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)

    FH="40-51"

    grbs = getgrib(year,month,day,roottime,FH)
    latlons = grbs

    #check parameters in gribfile
    grb_1 = grbs.select(name='Pressure reduced to MSL')[0]

    # lats,lonsは二次元配列で緯度経度が入っている
    lats, lons = grb_1.latlons()

    #一次元に変換
    # 二次元のままでは描画できない
    # 2次元の格子点を1次元配列にならす
    flat_lats= np.ravel(lats)
    flat_lons= np.ravel(lons)

    pd_rad= {'lons':flat_lons, 'lats':flat_lats}
    pd_Uwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_Vwind= {'lons':flat_lons, 'lats':flat_lats}
    pd_temp= {'lons':flat_lons, 'lats':flat_lats}

    i,j,k,l =0,0,0,0

    for grb in grbs:
        #print(grb)

        if grb.name == "Downward short-wave radiation flux":
            radiation = grb.values
            flat_radiation = np.ravel(radiation)
            pd_name="radiation FH"+str(i+40)+"-"+str(i+41)+"W/m2(avg)"
            pd_rad[pd_name]=flat_radiation
            i=i+1

        elif grb.name == "10 metre U wind component":
            Uwind = grb.values
            flat_Uwind = np.ravel(Uwind)
            pd_name="Uwind FH"+str(j+40)+"m/s"
            pd_Uwind[pd_name]=flat_Uwind
            j=j+1

        elif grb.name == "10 metre V wind component":
            Vwind = grb.values
            flat_Vwind = np.ravel(Vwind)
            pd_name="Vwind FH"+str(k+40)+"m/s"
            pd_Vwind[pd_name]=flat_Vwind
            k=k+1

        elif grb.name == "Temperature":
            temperature = grb.values
            #華氏を摂氏に変換
            flat_temperature= np.ravel(temperature)
            flat_temperature=flat_temperature-273.115
            pd_name="temperature FH"+str(l+40)
            pd_temp[pd_name]=flat_temperature
            l=l+1

    df_input1=pd.DataFrame(pd_temp)
    df_input2=pd.DataFrame(pd_Uwind)
    df_input3=pd.DataFrame(pd_Vwind)
    df_input4=pd.DataFrame(pd_rad)

    df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
    df_Uwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input2).reset_index()
    df_Vwind = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input3).reset_index()
    df_rad = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input4).reset_index()

    temp_name=new_dir_path+"/"+"FH_"+FH+"_"+"temperature" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_temp.to_csv(temp_name, encoding='utf-8', index=False)

    Uwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Uwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Uwind.to_csv(Uwind_name, encoding='utf-8', index=False)

    Vwind_name=new_dir_path+"/"+"FH_"+FH+"_"+"Vwind" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_Vwind.to_csv(Vwind_name, encoding='utf-8', index=False)

    rad_name=new_dir_path+"/"+"FH_"+FH+"_"+"radiation" + year + "_" + month + "_" + day+ "_" + roottime+".csv"
    df_rad.to_csv(rad_name, encoding='utf-8', index=False)
    
    day=int(day)
    day2=int(day2)
    
    if day == day2:
        print('break!')
        break
    else:
        day=day+1
        
    day=str(day)
    day2=str(day2)
# Out:
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201906150000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906150000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201906150000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201906150000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201906150000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201906150000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906150000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906150000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906150000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906150000
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201906150000
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906150000
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201906150000
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201906150000
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201906150000
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201906150000
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906150000
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906150000
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906150000
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906150000
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201906150000
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201906150000
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201906150000
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906150000
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201906150000
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201906150000
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201906150000
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201906150000
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906150000
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906150000
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906150000
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906150000
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201906150000
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201906150000
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201906150000
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906150000
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201906150000
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201906150000
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201906150000
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201906150000
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906150000
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906150000
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906150000
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906150000
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201906150000
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201906150000
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201906150000
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906150000
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201906150000
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201906150000
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201906150000
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201906150000
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906150000
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906150000
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906150000
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906150000
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201906150000
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201906150000
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201906150000
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906150000
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201906150000
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201906150000
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201906150000
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201906150000
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906150000
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906150000
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906150000
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906150000
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201906150000
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201906150000
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201906150000
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906150000
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201906150000
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201906150000
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201906150000
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201906150000
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906150000
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906150000
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906150000
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906150000
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201906150000
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201906150000
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201906150000
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906150000
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201906150000
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201906150000
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201906150000
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201906150000
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906150000
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906150000
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906150000
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906150000
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201906150000
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201906150000
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201906150000
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906150000
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201906150000
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201906150000
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201906150000
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201906150000
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906150000
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906150000
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906150000
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906150000
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201906150000
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201906150000
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201906150000
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906150000
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201906150000
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201906150000
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201906150000
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201906150000
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906150000
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906150000
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906150000
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906150000
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201906150000
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201906150000
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201906150000
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906150000
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201906150000
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201906150000
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201906150000
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201906150000
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906150000
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906150000
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906150000
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906150000
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201906150000
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201906150000
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201906150000
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906150000
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201906150000
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201906150000
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201906150000
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201906150000
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906150000
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906150000
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906150000
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906150000
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201906150000
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201906150000
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201906150000
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906150000
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201906150000
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201906150000
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201906150000
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201906150000
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906150000
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906150000
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906150000
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906150000
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201906150000
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201906150000
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201906150000
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906150000
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201906150000
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201906150000
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201906150000
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201906150000
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906150000
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906150000
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906150000
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906150000
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201906150000
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201906150000
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201906150000
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906150000
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201906150000
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201906150000
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201906150000
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201906150000
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906150000
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906150000
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906150000
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906150000
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201906150000
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201906150000
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201906150000
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906150000
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201906150000
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201906150000
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201906150000
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201906150000
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906150000
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906150000
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906150000
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906150000
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201906150000
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201906150000
#     index     lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  134846  130.375  33.6        20.137441        19.880667        19.768972
#
#    temperature FH3  temperature FH4  temperature FH5  temperature FH6  \
# 0        19.812246        20.081106        20.069052        20.171804
#
#    temperature FH7  temperature FH8  temperature FH9  temperature FH10  \
# 0        20.311086        20.401327        20.463796         20.149618
#
#    temperature FH11  temperature FH12  temperature FH13  temperature FH14  \
# 0          20.17153         20.387808         20.515829         20.602316
#
#    temperature FH15
# 0         20.665426
# 1:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 0 hrs:from 201906160000
# 2:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906160000
# 3:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201906160000
# 4:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 0 hrs:from 201906160000
# 5:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201906160000
# 6:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 0 hrs:from 201906160000
# 7:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906160000
# 8:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906160000
# 9:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906160000
# 10:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 0 hrs:from 201906160000
# 11:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 1 hrs:from 201906160000
# 12:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906160000
# 13:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201906160000
# 14:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 1 hrs:from 201906160000
# 15:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201906160000
# 16:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 1 hrs:from 201906160000
# 17:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906160000
# 18:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906160000
# 19:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906160000
# 20:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201906160000
# 21:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 0-1 hrs (accum):from 201906160000
# 22:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 0-1 hrs (avg):from 201906160000
# 23:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 2 hrs:from 201906160000
# 24:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906160000
# 25:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201906160000
# 26:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 2 hrs:from 201906160000
# 27:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201906160000
# 28:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 2 hrs:from 201906160000
# 29:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906160000
# 30:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906160000
# 31:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906160000
# 32:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201906160000
# 33:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 1-2 hrs (accum):from 201906160000
# 34:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 1-2 hrs (avg):from 201906160000
# 35:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 3 hrs:from 201906160000
# 36:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906160000
# 37:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201906160000
# 38:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 3 hrs:from 201906160000
# 39:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201906160000
# 40:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 3 hrs:from 201906160000
# 41:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906160000
# 42:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906160000
# 43:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906160000
# 44:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201906160000
# 45:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 2-3 hrs (accum):from 201906160000
# 46:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 2-3 hrs (avg):from 201906160000
# 47:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 4 hrs:from 201906160000
# 48:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906160000
# 49:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201906160000
# 50:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 4 hrs:from 201906160000
# 51:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201906160000
# 52:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 4 hrs:from 201906160000
# 53:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906160000
# 54:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906160000
# 55:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906160000
# 56:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201906160000
# 57:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 3-4 hrs (accum):from 201906160000
# 58:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 3-4 hrs (avg):from 201906160000
# 59:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 5 hrs:from 201906160000
# 60:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906160000
# 61:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201906160000
# 62:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 5 hrs:from 201906160000
# 63:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201906160000
# 64:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 5 hrs:from 201906160000
# 65:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906160000
# 66:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906160000
# 67:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906160000
# 68:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201906160000
# 69:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 4-5 hrs (accum):from 201906160000
# 70:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 4-5 hrs (avg):from 201906160000
# 71:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 6 hrs:from 201906160000
# 72:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906160000
# 73:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201906160000
# 74:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 6 hrs:from 201906160000
# 75:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201906160000
# 76:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 6 hrs:from 201906160000
# 77:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906160000
# 78:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906160000
# 79:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906160000
# 80:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201906160000
# 81:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 5-6 hrs (accum):from 201906160000
# 82:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 5-6 hrs (avg):from 201906160000
# 83:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 7 hrs:from 201906160000
# 84:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906160000
# 85:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201906160000
# 86:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 7 hrs:from 201906160000
# 87:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201906160000
# 88:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 7 hrs:from 201906160000
# 89:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906160000
# 90:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906160000
# 91:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906160000
# 92:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201906160000
# 93:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 6-7 hrs (accum):from 201906160000
# 94:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 6-7 hrs (avg):from 201906160000
# 95:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 8 hrs:from 201906160000
# 96:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906160000
# 97:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201906160000
# 98:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 8 hrs:from 201906160000
# 99:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201906160000
# 100:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 8 hrs:from 201906160000
# 101:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906160000
# 102:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906160000
# 103:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906160000
# 104:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201906160000
# 105:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 7-8 hrs (accum):from 201906160000
# 106:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 7-8 hrs (avg):from 201906160000
# 107:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 9 hrs:from 201906160000
# 108:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906160000
# 109:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201906160000
# 110:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 9 hrs:from 201906160000
# 111:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201906160000
# 112:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 9 hrs:from 201906160000
# 113:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906160000
# 114:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906160000
# 115:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906160000
# 116:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201906160000
# 117:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 8-9 hrs (accum):from 201906160000
# 118:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 8-9 hrs (avg):from 201906160000
# 119:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 10 hrs:from 201906160000
# 120:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906160000
# 121:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201906160000
# 122:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 10 hrs:from 201906160000
# 123:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201906160000
# 124:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 10 hrs:from 201906160000
# 125:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906160000
# 126:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906160000
# 127:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906160000
# 128:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201906160000
# 129:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 9-10 hrs (accum):from 201906160000
# 130:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 9-10 hrs (avg):from 201906160000
# 131:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 11 hrs:from 201906160000
# 132:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906160000
# 133:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201906160000
# 134:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 11 hrs:from 201906160000
# 135:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201906160000
# 136:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 11 hrs:from 201906160000
# 137:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906160000
# 138:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906160000
# 139:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906160000
# 140:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201906160000
# 141:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 10-11 hrs (accum):from 201906160000
# 142:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 10-11 hrs (avg):from 201906160000
# 143:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 12 hrs:from 201906160000
# 144:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906160000
# 145:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201906160000
# 146:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 12 hrs:from 201906160000
# 147:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201906160000
# 148:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 12 hrs:from 201906160000
# 149:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906160000
# 150:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906160000
# 151:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906160000
# 152:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201906160000
# 153:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 11-12 hrs (accum):from 201906160000
# 154:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 11-12 hrs (avg):from 201906160000
# 155:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 13 hrs:from 201906160000
# 156:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906160000
# 157:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201906160000
# 158:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 13 hrs:from 201906160000
# 159:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201906160000
# 160:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 13 hrs:from 201906160000
# 161:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906160000
# 162:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906160000
# 163:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906160000
# 164:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201906160000
# 165:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 12-13 hrs (accum):from 201906160000
# 166:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 12-13 hrs (avg):from 201906160000
# 167:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 14 hrs:from 201906160000
# 168:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906160000
# 169:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201906160000
# 170:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 14 hrs:from 201906160000
# 171:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201906160000
# 172:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 14 hrs:from 201906160000
# 173:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906160000
# 174:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906160000
# 175:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906160000
# 176:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201906160000
# 177:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 13-14 hrs (accum):from 201906160000
# 178:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 13-14 hrs (avg):from 201906160000
# 179:Pressure reduced to MSL:Pa (instant):regular_ll:meanSea:level 0:fcst time 15 hrs:from 201906160000
# 180:Surface pressure:Pa (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906160000
# 181:10 metre U wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201906160000
# 182:10 metre V wind component:m s**-1 (instant):regular_ll:heightAboveGround:level 10 m:fcst time 15 hrs:from 201906160000
# 183:Temperature:K (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201906160000
# 184:Relative humidity:% (instant):regular_ll:heightAboveGround:level 1.5 m:fcst time 15 hrs:from 201906160000
# 185:Low cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906160000
# 186:Medium cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906160000
# 187:High cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906160000
# 188:Total cloud cover:% (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201906160000
# 189:Total precipitation:kg m-2 (accum):regular_ll:surface:level 0:fcst time 14-15 hrs (accum):from 201906160000
# 190:Downward short-wave radiation flux:W m**-2 (avg):regular_ll:surface:level 0:fcst time 14-15 hrs (avg):from 201906160000
#     index     lons  lats  temperature FH0  temperature FH1  temperature FH2  \
# 0  134846  130.375  33.6        20.265249        20.422292        20.459768
#
#    temperature FH3  temperature FH4  temperature FH5  temperature FH6  \
# 0        20.502371        20.553304        20.726644        20.716696
#
#    temperature FH7  temperature FH8  temperature FH9  temperature FH10  \
# 0        20.656606        20.464529        20.339529         20.205953
#
#    temperature FH11  temperature FH12  temperature FH13  temperature FH14  \
# 0          20.23995         20.026907         19.743063         19.585989
#
#    temperature FH15
# 0         19.423605

# %%
elapsed_time = time.time() - start

print("elapsed_time:{0}".format(elapsed_time))
# Out:
# elapsed_time:124.2793378829956

# %%
#緯度経度の範囲を選択
east_lon=130.400
west_lon= 130.370
north_lat=33.62
south_lat=33.57
df_temp = range_ajust(east_lon,west_lon,north_lat,south_lat,df_input1).reset_index()
df_temp
# Out:
#     index     lons  lats  temperature FH40  temperature FH41  \
# 0  134846  130.375  33.6         19.862112         19.786398
#
#    temperature FH42  temperature FH43  temperature FH44  temperature FH45  \
# 0         19.742361         19.622396         19.517324         19.548147
#
#    temperature FH46  temperature FH47  temperature FH48  temperature FH49  \
# 0         20.187216         20.618124         21.080801         21.742605
#
#    temperature FH50  temperature FH51
# 0           22.3113         22.640951
